# %%
import pandas as pd

# %%
dfAcesso = pd.read_excel('compras_e_acessos.xlsx', sheet_name='acessos')
dfCompras = pd.read_excel('compras_e_acessos.xlsx', sheet_name='compras')

# %%
type(dfAcesso)
# Out:
# pandas.core.frame.DataFrame

# %%
dfAcesso
# Out:
#    user_id user_name  total
# 0        8     RENAN     10
# 1        3  GABRIELA      2
# 2        5    REBECA    399
# 3        6     PEDRO     21
# 4        7     JAMES      1

# %%
dfCompras
# Out:
#    user_id user_name  total
# 0        2      JOÃO     78
# 1        3  GABRIELA    100
# 2        5    REBECA     22
# 3        6     PEDRO    332
# 4        1   MARIANA     13

# %%
dfInnerJoin = dfAcesso.merge(dfCompras,how='inner', on='user_id')

# %%
dfInnerJoin
# Out:
#    user_id user_name_x  total_x user_name_y  total_y
# 0        3    GABRIELA        2    GABRIELA      100
# 1        5      REBECA      399      REBECA       22
# 2        6       PEDRO       21       PEDRO      332

# %%
dfLeftJoin = dfAcesso.merge(dfCompras,how='left', on='user_id')

# %%
dfLeftJoin
# Out:
#    user_id user_name_x  total_x user_name_y  total_y
# 0        8       RENAN       10         NaN      NaN
# 1        3    GABRIELA        2    GABRIELA    100.0
# 2        5      REBECA      399      REBECA     22.0
# 3        6       PEDRO       21       PEDRO    332.0
# 4        7       JAMES        1         NaN      NaN

# %%
dfRight = dfAcesso.merge(dfCompras,how='right', on='user_id')

# %%
dfRight
# Out:
#    user_id user_name_x  total_x user_name_y  total_y
# 0        2         NaN      NaN        JOÃO       78
# 1        3    GABRIELA      2.0    GABRIELA      100
# 2        5      REBECA    399.0      REBECA       22
# 3        6       PEDRO     21.0       PEDRO      332
# 4        1         NaN      NaN     MARIANA       13

# %%
dfOuter = dfAcesso.merge(dfCompras,how='outer', on='user_id')

# %%
dfOuter
# Out:
#    user_id user_name_x  total_x user_name_y  total_y
# 0        8       RENAN     10.0         NaN      NaN
# 1        3    GABRIELA      2.0    GABRIELA    100.0
# 2        5      REBECA    399.0      REBECA     22.0
# 3        6       PEDRO     21.0       PEDRO    332.0
# 4        7       JAMES      1.0         NaN      NaN
# 5        2         NaN      NaN        JOÃO     78.0
# 6        1         NaN      NaN     MARIANA     13.0

# %%
#Usuarios que tem acesso, mas nao tem comprar

dfLeftJoinindicatorTrue = dfAcesso.merge(dfCompras,how='left', on='user_id', indicator=True)

# %%
dfLeftJoinindicatorTrue
# Out:
#    user_id user_name_x  total_x user_name_y  total_y     _merge
# 0        8       RENAN       10         NaN      NaN  left_only
# 1        3    GABRIELA        2    GABRIELA    100.0       both
# 2        5      REBECA      399      REBECA     22.0       both
# 3        6       PEDRO       21       PEDRO    332.0       both
# 4        7       JAMES        1         NaN      NaN  left_only

# %%
dfLeftJoinindicatorTrue = dfLeftJoinindicatorTrue[dfLeftJoinindicatorTrue._merge == 'left_only']

# %%
dfLeftJoinindicatorTrue
# Out:
#    user_id user_name_x  total_x user_name_y  total_y     _merge
# 0        8       RENAN       10         NaN      NaN  left_only
# 4        7       JAMES        1         NaN      NaN  left_only

# %%
#Usuarios que tem compras, mas nao tem acesso
dfrightJoinindicatorTrue = dfAcesso.merge(dfCompras,how='right', on='user_id', indicator=True)

# %%
dfrightJoinindicatorTrue
# Out:
#    user_id user_name_x  total_x user_name_y  total_y      _merge
# 0        2         NaN      NaN        JOÃO       78  right_only
# 1        3    GABRIELA      2.0    GABRIELA      100        both
# 2        5      REBECA    399.0      REBECA       22        both
# 3        6       PEDRO     21.0       PEDRO      332        both
# 4        1         NaN      NaN     MARIANA       13  right_only

# %%
dfrightJoinindicatorTrue = dfrightJoinindicatorTrue[dfrightJoinindicatorTrue._merge == 'right_only']

# %%
dfrightJoinindicatorTrue
# Out:
#    user_id user_name_x  total_x user_name_y  total_y      _merge
# 0        2         NaN      NaN        JOÃO       78  right_only
# 4        1         NaN      NaN     MARIANA       13  right_only
